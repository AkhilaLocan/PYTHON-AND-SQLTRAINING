# %% [markdown]
# # Python Data Structures and Copying
#
# ## Action Items
#
# - **Submit project idea** to the instructor by Tuesday night (avoid simple to‑do lists; aim for analytics/ML potential).
# - **Message the instructor** once your idea is finalized for feedback.
# - Review the uploaded assignment files and questions when they become available.
#
# ## Data Structures Overview
#
# - **Lists** – mutable, allow mixed data types, indexed from 0, support slicing.
# - **Tuples** – immutable counterpart to lists; created with parentheses; same indexing/slicing.
# - Convert tuple → list → modify → back to tuple when you need to “update” a tuple.
# - **Sets** – unordered collection of unique elements; duplicates automatically removed.
#   - add, remove (error if missing) vs. discard (silent if missing).
#   - pop removes an arbitrary element (order not guaranteed).
# - **Dictionaries** – key‑value pairs in curly braces; keys can be any immutable type.
#   - Access via dict\[key\]; nested dictionaries and mixed‑type values supported.
#   - Useful built‑ins: .keys(), .values(), .items(), and dictionary comprehensions for concise creation.
#
#
# ## Functions & Return vs. Print
#
# - Define a function with def name(params):.
# - **print** – displays output to console, returns None; cannot be reused in calculations.
# - **return** – sends a value back to the caller; can be stored in variables and reused.
# - Example: sum function returning the result vs. printing it; the returned value can be further added or processed.
#
# ## Example: Prime‑Number Checker
#
# - Loop from 2 to n‑1; if any divisor yields zero remainder, number is not prime.
# - Break early on first divisor found; otherwise declare prime.
#
# ## Upcoming Schedule & Assessments
#
# - **Python basics** – completed by Monday/Tuesday.
# - **Object‑Oriented Programming** – Wednesday & Thursday.
# - **Data Visualization** – Friday.
# - **Python assessment** – after basic sessions; build an application that can later expand to:
#   - Database integration (SQL)
#   - Machine learning / generative AI
#   - Data warehousing & analytics
#
# ## Project Idea Guidelines
#
# - Must be more than a simple utility (e.g., habit tracker, calculator).
# - Should have clear extension paths: analytics, visualization, predictive modeling, or generative AI.
# - Think of real‑world problems you face (gym tracking, personal finance, content summarization, etc.).
# - Avoid ideas that already exist as basic tutorials; aim for something you can grow throughout the course.

# %% [markdown]
# # TUPLE
# - Tuples – immutable counterpart to lists; created with parentheses; same indexing/slicing.
# - Convert tuple → list → modify → back to tuple when you need to “update” a tuple.

# %%
 # TUPLE
t= (1,2,3,4,5,6)
type(t)
# Out:
# tuple

# %%
t= (1, 'apple', 2, 'ant')
t.count('1')
# Out:
# 0

# %%
t = (10, 20, 30)
for x in t:
    print(x)
# Out:
# 10
# 20
# 30

# %%
t = (1, 2, 3, 4)
print(len(t))
# Out:
# 4

# %%
a = (1, 2)
b = (3, 4)
c = a + b
print(c)
# Out:
# (1, 2, 3, 4)

# %%
#CONVERT TUPLE TO LIST MAKE CHANGES AND CONVERT TO TUPLE
x=(1,2,3,4,5)
print(type(x))
temp_list= list(x)
temp_list.append(4)
print(type(temp_list))
print(f"list: {temp_list} ")
x= tuple(temp_list)
print(f"tuple:{x}")
# Out:
# <class 'tuple'>
# <class 'list'>
# list: [1, 2, 3, 4, 5, 4]
# tuple:(1, 2, 3, 4, 5, 4)

# %% [markdown]
# # SET
# - Sets – unordered collection of unique elements; duplicates automatically removed.
# - add, remove (error if missing) vs. discard (silent if missing).
# - pop removes an arbitrary element (order not guaranteed).

# %%
x= set()
x
# Out:
# set()

# %%
x.add(2)

# %%
s = {1, 1, 2, 2, 3}
print(s)
# Out:
# {1, 2, 3}

# %%
s= {1,2,3,3,4,5,6,7}
s.pop()
s
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
s.pop()
# Out:
# 2

# %%
s = {1, 2, 3}
s.discard(10)    #no error even if it is not present
print(s)
# Out:
# {1, 2, 3}

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a - b)          # {1,2}
# Out:
# {1, 2}

# %%
squares = {x*x for x in range(1, 6)}
print(squares)
# Out:
# {1, 4, 9, 16, 25}

# %% [markdown]
# # DICTIONARY
# - Dictionaries – key‑value pairs in curly braces; keys can be any immutable type.
# - Access via dict[key]; nested dictionaries and mixed‑type values supported.
# - Useful built‑ins: .keys(), .values(), .items(), and dictionary comprehensions for concise creation.

# %%
student = {"name": "akhila", "age": 25, "city": "NYC"}
print(student)
# Out:
# {'name': 'akhila', 'age': 25, 'city': 'NYC'}

# %%
for key in student:
    print(key, student[key])
# Out:
# name akhila
# age 25
# city NYC

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name akhila
# age 25
# city NYC

# %%
## NESTED DICTIONARY

# %%
user = { "id": 101, "profile": {"name": "akhila", "email": "akhila@gmail.com"}}
print(user["profile"]["email"])
# Out:
# akhila@gmail.com

# %%
#DICT COMPREHENSION

# %%
squares = {x: x*x for x in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# # Shallow vs. Deep Copy
# - Shallow copy (copy.copy()): new container, but inner objects reference the same memory; changes to nested items affect the original.
# - Deep copy (copy.deepcopy()): fully independent clone; modifications stay isolated.
# ### Typical use cases:
# - Shallow copy for quick, temporary tweaks where original can change.
# - Deep copy when you need a stable “raw” version (e.g., ETL pipelines, experiment isolation).

# %%
import copy

a = [[1, 2], [3, 4]]
shallow= copy.copy(a)      

shallow[0].append(99)

print("a:", a)  
print("b:", b)
# Out:
# a: [[1, 2, 99], [3, 4]]
# b: [1, 2, 3, 4, 99]

# %%
import copy

original = [1,2,3,4] 

shallow = copy.copy(original)

shallow[0] = 12

print('original', original)
print('shallow', shallow)
# Out:
# original [1, 2, 3, 4]
# shallow [12, 2, 3, 4]

# %%
#deep copy 

import copy

original = [[1,2],[3,4]] 

deep = copy.deepcopy(original)

deep[0][0] = 12

print('original', original)
print('Deep', deep)
# Out:
# original [[1, 2], [3, 4]]
# Deep [[12, 2], [3, 4]]

# %%
import copy

a = [1,2,3,4]
deep = copy.copy(a)      

deep.append(99)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 99]

# %%
import copy

a = [[1, 2], [3, 4]]
b = copy.deepcopy(a)

b[0].append(99)

print("a:", a)  
print("b:", b)
# Out:
# a: [[1, 2], [3, 4]]
# b: [[1, 2, 99], [3, 4]]

# %% [markdown]
# # Functions & Return vs. Print
#
# - write code one time, use it everytime.
# - A function groups a set of statements together to run the statements more than once. It allows us to specify parameters that can serve as inputs to the functions.
#
# - Functions allow us to reuse the code instead of writing the code again and again. If you recall strings and lists, remember that len() function is used to find the length of a string. Since checking the length of a sequence is a common task, you would want to write a function that can do this repeatedly at command.
#
# - Function is one of the most basic levels of reusing code in Python, and it will also allow us to start thinking of program design.

# %%
def add(a, b):
    return a + b

result = add(10, 20)
print(result)
# Out:
# 30

# %%
def is_even(n):
    return n % 2 == 0

print(is_even(10))  
print(is_even(7))
# Out:
# True
# False

# %%
def print_num(n):
    for i in range(1,n+1):
        print(i*n)

print_num(8)
# Out:
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64

# %% [markdown]
# # def statement
#
# - Define a function with def name(params)

# %%
def say_hello():
    print('hello')

# %%
def greeting(name):
    print(f'Hello {name}!')

# %%
greeting('Jack')
# Out:
# Hello Jack!

# %% [markdown]
# # print vs return
# - **print** – displays output , returns None; cannot be reused in calculations.
# - **return** – sends a value back to the caller; can be stored in variables and reused.
# - Example: sum function returning the result vs. printing it; the returned value can be further added or processed.

# %%
def add_num(num1,num2):
    return num1+num2

# %%
add_num(5,6)
# Out:
# 11

# %%
# Can also save as variable due to return
result = add_num(5,6)
result
# Out:
# 11

# %%
print(result + 5)
# Out:
# 16

# %%
def add_num(num1,num2):
    print(num1+num2)

x = add_num(5,6) 
print(x + 6 )
# Out:
# 11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 5
#       2     print(num1+num2)
#       4 x = add_num(5,6)
# ----> 5 print(x + 6 )
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def func_with_print():
    print("Hello")

def func_with_return():
    return "Hello"

# Call both and store results
a = func_with_print()
b = func_with_return()

print("a =", a)  # Will print: a = None
print("b =", b)  # Will print: b = Hello
# Out:
# Hello
# a = None
# b = Hello

# %%
# What happens if we input two strings?
print(add_num(2,3))
# Out:
# 5
# None

# %% [markdown]
# - In Python we don't declare variable types, this function could be used to add numbers or sequences together! Going forward, We'll learn about adding in checks to make sure a user puts in the correct arguments into a function.
# - Let's also start using break,continue, and pass statements in our code. We introduced these during the while lecture.

# %% [markdown]
# - Now, let's see a complete example of creating a function to check if a number is prime (a common interview exercise).
#
# - We know a number is said to be prime if that number is only divisible by 1 and itself. Let's write our first version of the function to check all the numbers from 1 to N and perform modulo checks.

# %%
def is_prime(num):
    '''
    Naive method of checking for primes. 
    '''
    for n in range(2,num):
        if num % n == 0:
            print('not prime')
            break
    else: # If never mod zero, then prime
        print('prime')
